# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv('../data/processed/20newsgroup_preprocessed.csv')
df.head()
